# %%
from shopping_list import ShoppingList
shopping_list = {
    "Cheddar":        {"category": "Cheese",        "weight": 2, "hardness": 3},
    "Cashews":        {"category": "Nuts",          "weight": 1, "hardness": 4},
    "Penne":          {"category": "Pasta",         "weight": 1, "hardness": 2},
    "Pizza":          {"category": "Frozen Meals",  "weight": 3, "hardness": 4},
    "Bandnudeln":     {"category": "Pasta",         "weight": 1, "hardness": 2},
    "Blumen":         {"category": "Promotion",    "weight": 1, "hardness": 1}
}
shopping_list = ShoppingList.from_dict(shopping_list) 
shopping_list.save_to_file("small_shopping_list.txt")

# %%
from shopping_list import ShoppingList
# Best possible Route:
# Best Cost: 24
shopping_list = {
    "Flowers":          {"category": "Promotion",       "weight": 1, "hardness": 1},
    "Apple":            {"category": "Fruits",          "weight": 1, "hardness": 2},
    "Banana":           {"category": "Fruits",          "weight": 1, "hardness": 1},
    "Carrot":           {"category": "Vegetables",      "weight": 1, "hardness": 3},
    "Broccoli":         {"category": "Vegetables",      "weight": 2, "hardness": 2},
    "Water":            {"category": "Water",           "weight": 4, "hardness": 5},
    "Soy Milk":         {"category": "Vegan Products",  "weight": 2, "hardness": 3},
    "Lasagna":          {"category": "Ready Meals",     "weight": 3, "hardness": 4},
    "Cashews":          {"category": "Nuts",            "weight": 1, "hardness": 4},
    "Almonds":          {"category": "Nuts",            "weight": 1, "hardness": 4},
    "Tuna":             {"category": "Canned Goods",    "weight": 3, "hardness": 5},
    "Cheddar":          {"category": "Cheese",          "weight": 2, "hardness": 3},
    "Mozzarella":       {"category": "Cheese",          "weight": 2, "hardness": 2},
    "Salmon":           {"category": "Fish",            "weight": 3, "hardness": 3},
    "Chicken Breast":   {"category": "Meat/Cold Cuts",  "weight": 3, "hardness": 2},
    "Sausage":          {"category": "Meat/Cold Cuts",  "weight": 3, "hardness": 4},
    "Tabasco":          {"category": "Spices",          "weight": 1, "hardness": 5},
    "Croissant":        {"category": "Bakery",          "weight": 1, "hardness": 1},
    "Baguette":         {"category": "Bakery",          "weight": 2, "hardness": 2},
    "Beer":             {"category": "Alcohol",         "weight": 5, "hardness": 5},
    "Spezi":            {"category": "Beverages",       "weight": 3, "hardness": 5},
    "Orange Juice":     {"category": "Juices",          "weight": 3, "hardness": 5},
    "Toiletpaper":      {"category": "Household",       "weight": 2, "hardness": 1},
    "Cracker":          {"category": "Snacks",          "weight": 1, "hardness": 2},
    "Chocolate":        {"category": "Chocolate",       "weight": 2, "hardness": 3},
    "Frozen Burritos":  {"category": "Frozen Meals",    "weight": 3, "hardness": 4},
    "Pizza":            {"category": "Frozen Pizzas",   "weight": 3, "hardness": 4}
}

shopping_list = ShoppingList.from_dict(shopping_list)
shopping_list.save_to_file("Long_shopping_list.txt")
