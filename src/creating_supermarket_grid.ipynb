# %%
from supermarket import Grid

# Beispiel-Grid erzeugen
grid_size = (6,6)
grid = Grid(grid_size=grid_size)


# Beispiel-Konfiguration
# Zeile 1
grid.grid[0,2].seiten["N"] = "Käse"
grid.grid[0,2].seiten["W"] = "Fisch"
grid.grid[0,3].seiten["N"] = "Konserven"
grid.grid[0,4].seiten["N"] = "Nüsse"
grid.grid[0,5].seiten["N"] = "Milchprodukte"
grid.grid[0,5].seiten["E"] = "Milchprodukte"

# Zeile 2
grid.grid[1,2].seiten["W"] = "Wurst/Fleisch"
grid.grid[1,3].seiten["W"] = "International"
grid.grid[1,3].seiten["E"] = "International"
grid.grid[1,4].seiten["W"] = "Tchibo"
grid.grid[1,4].seiten["E"] = "Brote"
grid.grid[1,5].seiten["W"] = "Frühstück"
grid.grid[1,5].seiten["E"] = "Fertiggerichte"

# Zeile 3
grid.grid[2,1].seiten["W"] = "Bäckerei"
grid.grid[2,1].seiten["N"] = "Bäckerei"
grid.grid[2,2].seiten["S"] = "Gewürze"
grid.grid[2,3].seiten["S"] = "Nudeln"
grid.grid[2,4].seiten["S"] = "Reis"
grid.grid[2,5].seiten["E"] = "Vegane Produkte"

# Zeile 4
grid.grid[3,0].seiten["W"] = "Tiefkühlgerichte"
grid.grid[3,0].seiten["N"] = "Tiefkühlgerichte"
grid.grid[3,1].seiten["S"] = "Alkohol"
grid.grid[3,2].seiten["N"] = "Getränke"
grid.grid[3,2].seiten["S"] = "Getränke"
grid.grid[3,3].seiten["N"] = "Säfte"
grid.grid[3,4].seiten["N"] = "Wasser"
grid.grid[3,4].seiten["S"] = "Wasser"
grid.grid[3,5].seiten["E"] = "Gekühltes Gemüse"

# Zeile 5
grid.grid[4,0].seiten["W"] = "Tiefkühlpizzen"
grid.grid[4,1].seiten["N"] = "Schokolade"
grid.grid[4,1].seiten["S"] = "Schokolade"
grid.grid[4,2].seiten["N"] = "Snacks"
grid.grid[4,2].seiten["S"] = "Snacks"
grid.grid[4,3].seiten["E"] = "Haushalt"
grid.grid[4,3].seiten["S"] = "Haushalt"
grid.grid[4,4].seiten["N"] = "Obst"
grid.grid[4,4].seiten["W"] = "Obst"
grid.grid[4,5].seiten["E"] = "Gemüse"
grid.grid[4,5].seiten["S"] = "Gemüse"

# Zeile 6
grid.grid[5,0].seiten["E"] = 1
grid.grid[5,0].seiten["W"] = 1
grid.grid[5,4].seiten["E"] = "Aktion"
grid.grid[5,4].seiten["W"] = "Aktion"
      

grid.plot()
grid.save("grid.txt")

# %%
from supermarket import Grid

# Example grid
grid_size = (6,6)
grid = Grid(grid_size=grid_size)

# Example configuration
# Row 1
grid.grid[0,2].seiten["N"] = "Cheese"
grid.grid[0,2].seiten["W"] = "Fish"
grid.grid[0,3].seiten["N"] = "Canned Goods"
grid.grid[0,4].seiten["N"] = "Nuts"
grid.grid[0,5].seiten["N"] = "Dairy"
grid.grid[0,5].seiten["E"] = "Dairy"

# Row 2
grid.grid[1,2].seiten["W"] = "Meat/Cold Cuts"
grid.grid[1,3].seiten["W"] = "International"
grid.grid[1,3].seiten["E"] = "International"
grid.grid[1,4].seiten["W"] = "Coffee"
grid.grid[1,4].seiten["E"] = "Bread"
grid.grid[1,5].seiten["W"] = "Breakfast"
grid.grid[1,5].seiten["E"] = "Ready Meals"

# Row 3
grid.grid[2,1].seiten["W"] = "Bakery"
grid.grid[2,1].seiten["N"] = "Bakery"
grid.grid[2,2].seiten["S"] = "Spices"
grid.grid[2,3].seiten["S"] = "Pasta"
grid.grid[2,4].seiten["S"] = "Rice"
grid.grid[2,5].seiten["E"] = "Vegan Products"

# Row 4
grid.grid[3,0].seiten["W"] = "Frozen Meals"
grid.grid[3,0].seiten["N"] = "Frozen Meals"
grid.grid[3,1].seiten["S"] = "Alcohol"
grid.grid[3,2].seiten["N"] = "Beverages"
grid.grid[3,2].seiten["S"] = "Beverages"
grid.grid[3,3].seiten["N"] = "Juices"
grid.grid[3,4].seiten["N"] = "Water"
grid.grid[3,4].seiten["S"] = "Water"
grid.grid[3,5].seiten["E"] = "Chilled Vegetables"

# Row 5
grid.grid[4,0].seiten["W"] = "Frozen Pizzas"
grid.grid[4,1].seiten["N"] = "Chocolate"
grid.grid[4,1].seiten["S"] = "Chocolate"
grid.grid[4,2].seiten["N"] = "Snacks"
grid.grid[4,2].seiten["S"] = "Snacks"
grid.grid[4,3].seiten["E"] = "Household"
grid.grid[4,3].seiten["S"] = "Household"
grid.grid[4,4].seiten["N"] = "Fruits"
grid.grid[4,4].seiten["W"] = "Fruits"
grid.grid[4,5].seiten["E"] = "Vegetables"
grid.grid[4,5].seiten["S"] = "Vegetables"

# Row 6
grid.grid[5,0].seiten["E"] = 1
grid.grid[5,0].seiten["W"] = 1
grid.grid[5,4].seiten["E"] = "Promotion"
grid.grid[5,4].seiten["W"] = "Promotion"

# Plot and save
grid.plot()
grid.save("grid_eng.txt")
